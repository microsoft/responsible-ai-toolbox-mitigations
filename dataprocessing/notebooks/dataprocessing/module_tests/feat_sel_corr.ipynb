# %% [markdown]
# # CorrelatedFeatures Example

# %%
import pandas as pd
import numpy as np
from raimitigations.dataprocessing import CorrelatedFeatures

# %% [markdown]
# # 1 - HR Dataset

# %%
data_dir = '../../../datasets/hr_promotion'
df =  pd.read_csv(data_dir + '/train.csv')
df.drop(columns=['employee_id'], inplace=True)
df
# Out:
#               department     region         education gender  \
# 0      Sales & Marketing   region_7  Master's & above      f
# 1             Operations  region_22        Bachelor's      m
# 2      Sales & Marketing  region_19        Bachelor's      m
# 3      Sales & Marketing  region_23        Bachelor's      m
# 4             Technology  region_26        Bachelor's      m
# ...                  ...        ...               ...    ...
# 54803         Technology  region_14        Bachelor's      m
# 54804         Operations  region_27  Master's & above      f
# 54805          Analytics   region_1        Bachelor's      m
# 54806  Sales & Marketing   region_9               NaN      m
# 54807                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   35                   5.0
# 1                   other                1   30                   5.0
# 2                sourcing                1   34                   3.0
# 3                   other                2   39                   1.0
# 4                   other                1   45                   3.0
# ...                   ...              ...  ...                   ...
# 54803            sourcing                1   48                   3.0
# 54804               other                1   37                   2.0
# 54805               other                1   27                   5.0
# 54806            sourcing                1   29                   1.0
# 54807               other                1   27                   1.0
#
#        length_of_service  awards_won?  avg_training_score  is_promoted
# 0                      8            0                  49            0
# 1                      4            0                  60            0
# 2                      7            0                  50            0
# 3                     10            0                  50            0
# 4                      2            0                  73            0
# ...                  ...          ...                 ...          ...
# 54803                 17            0                  78            0
# 54804                  6            0                  56            0
# 54805                  3            0                  79            0
# 54806                  2            0                  45            0
# 54807                  5            0                  49            0
#
# [54808 rows x 12 columns]

# %%
label_col = "is_promoted"
cor_feat = CorrelatedFeatures(
					method_num_num=["spearman", "pearson", "kendall"],
					method_num_cat="model",
					save_json=False
				)
cor_feat.fit(df=df, label_col=label_col)
_ = cor_feat.get_summary()
# Out:
# No correlations detected. Nothing to be done here.
#
# CORRELATION SUMMARY
#
#
# NOT CORRELATED VARIABLES SUMMARY
#
# department x region:
# 	* Cramer's V = 0.1342 with a p-value of 0.0
# department x education:
# 	* Cramer's V = 0.1243 with a p-value of 0.0
# department x gender:
# 	* Cramer's V = 0.2866 with a p-value of 0.0
# department x recruitment_channel:
# 	* Cramer's V = 0.0634 with a p-value of 0.0
# department x no_of_trainings:
# 	Model metrics:
# 	precision = 0.12673642797753037
# 	recall = 0.11134860176670285
# 	f1 = 0.052750960416829404
# 	auc = 0.500139246590814
# 	accuracy = 0.30748646840600863
# department x age:
# 	Model metrics:
# 	precision = 0.034138133754991994
# 	recall = 0.1111111111111111
# 	f1 = 0.052229200589284326
# 	auc = 0.5
# 	accuracy = 0.3072432037949279
# department x previous_year_rating:
# 	Model metrics:
# 	precision = 0.0340435792888772
# 	recall = 0.1111111111111111
# 	f1 = 0.052118466314288105
# 	auc = 0.5
# 	accuracy = 0.30639221359989477
# department x length_of_service:
# 	Model metrics:
# 	precision = 0.0795524422562426
# 	recall = 0.11128121055704843
# 	f1 = 0.054389562514085256
# 	auc = 0.5001154350934296
# 	accuracy = 0.30645259380891565
# department x awards_won?:
# 	Model metrics:
# 	precision = 0.034138133754991994
# 	recall = 0.1111111111111111
# 	f1 = 0.052229200589284326
# 	auc = 0.5
# 	accuracy = 0.3072432037949279
# department x avg_training_score:
# 	Model metrics:
# 	precision = 0.4247600770799073
# 	recall = 0.4802623389943179
# 	f1 = 0.4502332249231271
# 	auc = 0.7244108224578368
# 	accuracy = 0.7742504409171076
# region x education:
# 	* Cramer's V = 0.1825 with a p-value of 0.0
# region x gender:
# 	* Cramer's V = 0.1633 with a p-value of 0.0
# region x recruitment_channel:
# 	* Cramer's V = 0.1132 with a p-value of 0.0
# region x no_of_trainings:
# 	Model metrics:
# 	precision = 0.02133028261484023
# 	recall = 0.029427019770563827
# 	f1 = 0.010843799075186546
# 	auc = 0.5000089229973987
# 	accuracy = 0.22526302986073102
# region x age:
# 	Model metrics:
# 	precision = 0.013169643902646147
# 	recall = 0.03783068596921626
# 	f1 = 0.019451825027122074
# 	auc = 0.505101610199303
# 	accuracy = 0.24448093413610655
# region x previous_year_rating:
# 	Model metrics:
# 	precision = 0.006694338921942577
# 	recall = 0.029411764705882353
# 	f1 = 0.010906317849366135
# 	auc = 0.5
# 	accuracy = 0.2276075233460476
# region x length_of_service:
# 	Model metrics:
# 	precision = 0.006623594520822377
# 	recall = 0.029411764705882353
# 	f1 = 0.010812247066999141
# 	auc = 0.5
# 	accuracy = 0.22520221370796084
# region x awards_won?:
# 	Model metrics:
# 	precision = 0.006623594520822377
# 	recall = 0.029411764705882353
# 	f1 = 0.010812247066999141
# 	auc = 0.5
# 	accuracy = 0.22520221370796084
# region x avg_training_score:
# 	Model metrics:
# 	precision = 0.011944665224893614
# 	recall = 0.031686544912657155
# 	f1 = 0.01579271552707691
# 	auc = 0.5013451985241933
# 	accuracy = 0.22526302986073102
# education x gender:
# 	* Cramer's V = 0.028 with a p-value of 0.0
# education x recruitment_channel:
# 	* Cramer's V = 0.0274 with a p-value of 0.0
# education x no_of_trainings:
# 	Model metrics:
# 	precision = 0.23326972010178115
# 	recall = 0.3333333333333333
# 	f1 = 0.27446577598143784
# 	auc = 0.5
# 	accuracy = 0.6998091603053435
# education x age:
# 	Model metrics:
# 	precision = 0.6462327076706303
# 	recall = 0.41536885264727963
# 	f1 = 0.4319039997485514
# 	auc = 0.5549199112440789
# 	accuracy = 0.703944020356234
# education x previous_year_rating:
# 	Model metrics:
# 	precision = 0.22882129972142304
# 	recall = 0.3333333333333333
# 	f1 = 0.2713622270062418
# 	auc = 0.5
# 	accuracy = 0.6864638991642691
# education x length_of_service:
# 	Model metrics:
# 	precision = 0.4120275158284287
# 	recall = 0.3522722439311044
# 	f1 = 0.3244254547222834
# 	auc = 0.518291441393599
# 	accuracy = 0.7022264631043257
# education x awards_won?:
# 	Model metrics:
# 	precision = 0.23326972010178115
# 	recall = 0.3333333333333333
# 	f1 = 0.27446577598143784
# 	auc = 0.5
# 	accuracy = 0.6998091603053435
# education x avg_training_score:
# 	Model metrics:
# 	precision = 0.3443913827867982
# 	recall = 0.3334025205417668
# 	f1 = 0.27511219860120967
# 	auc = 0.5000629311169876
# 	accuracy = 0.6994910941475827
# gender x recruitment_channel:
# 	* Cramer's V = 0.0097 with a p-value of 0.0769
# gender x no_of_trainings:
# 	Model metrics:
# 	precision = 0.35118287417137994
# 	recall = 0.5
# 	f1 = 0.4125821663332381
# 	auc = 0.5
# 	accuracy = 0.7023657483427599
# gender x age:
# 	Model metrics:
# 	precision = 0.35118287417137994
# 	recall = 0.5
# 	f1 = 0.4125821663332381
# 	auc = 0.5
# 	accuracy = 0.7023657483427599
# gender x previous_year_rating:
# 	Model metrics:
# 	precision = 0.3505195317637775
# 	recall = 0.5
# 	f1 = 0.4121240238150468
# 	auc = 0.5
# 	accuracy = 0.701039063527555
# gender x length_of_service:
# 	Model metrics:
# 	precision = 0.503361489170153
# 	recall = 0.5000224607554252
# 	f1 = 0.4137730191172389
# 	auc = 0.5000224607554251
# 	accuracy = 0.7018184029678283
# gender x awards_won?:
# 	Model metrics:
# 	precision = 0.35118287417137994
# 	recall = 0.5
# 	f1 = 0.4125821663332381
# 	auc = 0.5
# 	accuracy = 0.7023657483427599
# gender x avg_training_score:
# 	Model metrics:
# 	precision = 0.35118287417137994
# 	recall = 0.5
# 	f1 = 0.4125821663332381
# 	auc = 0.5
# 	accuracy = 0.7023657483427599
# recruitment_channel x no_of_trainings:
# 	Model metrics:
# 	precision = 0.38518067891470986
# 	recall = 0.33340390036726925
# 	f1 = 0.23835979510924601
# 	auc = 0.5000685194533437
# 	accuracy = 0.5555555555555556
# recruitment_channel x age:
# 	Model metrics:
# 	precision = 0.18516491313426178
# 	recall = 0.3333333333333333
# 	f1 = 0.23807848196947778
# 	auc = 0.5
# 	accuracy = 0.5554947394027854
# recruitment_channel x previous_year_rating:
# 	Model metrics:
# 	precision = 0.1853654259283616
# 	recall = 0.3333333333333333
# 	f1 = 0.2382441608204435
# 	auc = 0.5
# 	accuracy = 0.5560962777850849
# recruitment_channel x length_of_service:
# 	Model metrics:
# 	precision = 0.2684824705476813
# 	recall = 0.3332717037425968
# 	f1 = 0.23813316153868122
# 	auc = 0.49993922882963143
# 	accuracy = 0.5553731070972451
# recruitment_channel x awards_won?:
# 	Model metrics:
# 	precision = 0.18516491313426178
# 	recall = 0.3333333333333333
# 	f1 = 0.23807848196947778
# 	auc = 0.5
# 	accuracy = 0.5554947394027854
# recruitment_channel x avg_training_score:
# 	Model metrics:
# 	precision = 0.33958779716355475
# 	recall = 0.3337187540227662
# 	f1 = 0.24236047422764354
# 	auc = 0.5003812526409933
# 	accuracy = 0.5551906586389345
# no_of_trainings x age:
# 	* spearman correlation = -0.08567734669750156 with a p-value of 8.24159483672033e-90
# 	* pearson correlation = -0.08127788515891331 with a p-value of 5.515586459857862e-81
# 	* kendall correlation = -0.07033540017324696 with a p-value of 6.620727279462055e-90
# no_of_trainings x previous_year_rating:
# 	* spearman correlation = -0.058165006261934805 with a p-value of 3.061451995626692e-39
# 	* pearson correlation = -0.06312647310177316 with a p-value of 6.358532772309025e-46
# 	* kendall correlation = -0.05187495857339066 with a p-value of 3.448682684824809e-39
# no_of_trainings x length_of_service:
# 	* spearman correlation = -0.05689234206825611 with a p-value of 1.5568764001787374e-40
# 	* pearson correlation = -0.057274782159258 with a p-value of 4.65646361009503e-41
# 	* kendall correlation = -0.04765905219251409 with a p-value of 1.520099733020833e-40
# no_of_trainings x awards_won?:
# 	* spearman correlation = -0.00726207518474017 with a p-value of 0.08910911969759157
# 	* pearson correlation = -0.007628320490092272 with a p-value of 0.07412198807468749
# 	* kendall correlation = -0.007133053508924031 with a p-value of 0.08910895989684842
# no_of_trainings x avg_training_score:
# 	* spearman correlation = 0.052675622346956566 with a p-value of 5.499652720110723e-35
# 	* pearson correlation = 0.04251700309735751 with a p-value of 2.327496956930897e-23
# 	* kendall correlation = 0.04278505888744279 with a p-value of 6.608687900771465e-35
# age x previous_year_rating:
# 	* spearman correlation = 0.011070078241166702 with a p-value of 0.012694255962507566
# 	* pearson correlation = 0.006008233548997271 with a p-value of 0.17617740734218768
# 	* kendall correlation = 0.008357522780838568 with a p-value of 0.012916484671334593
# age x length_of_service:
# 	* spearman correlation = 0.644444228689948 with a p-value of 0.0
# 	* pearson correlation = 0.6571113793687711 with a p-value of 0.0
# 	* kendall correlation = 0.5004580340909148 with a p-value of 0.0
# age x awards_won?:
# 	* spearman correlation = -0.006438835602542054 with a p-value of 0.13171224944980608
# 	* pearson correlation = -0.008168820710409207 with a p-value of 0.05582493811084624
# 	* kendall correlation = -0.005368736552559253 with a p-value of 0.13171096753540878
# age x avg_training_score:
# 	* spearman correlation = -0.04100126771404651 with a p-value of 7.7899757218145e-22
# 	* pearson correlation = -0.0483796889694133 with a p-value of 9.047949740018981e-30
# 	* kendall correlation = -0.028593255745523037 with a p-value of 2.9172605193778375e-22
# previous_year_rating x length_of_service:
# 	* spearman correlation = 0.002770012275408665 with a p-value of 0.5328892256606554
# 	* pearson correlation = 0.00025274601630482314 with a p-value of 0.9546251894489995
# 	* kendall correlation = 0.0021549706897756415 with a p-value of 0.5316658414725104
# previous_year_rating x awards_won?:
# 	* spearman correlation = 0.02801139111471694 with a p-value of 2.8391481692599116e-10
# 	* pearson correlation = 0.02773815506176426 with a p-value of 4.2172207602058987e-10
# 	* kendall correlation = 0.02541948830200153 with a p-value of 2.8602057553670853e-10
# previous_year_rating x avg_training_score:
# 	* spearman correlation = 0.07680642018407081 with a p-value of 3.521666787964453e-67
# 	* pearson correlation = 0.07513911178909113 with a p-value of 2.2936476588197927e-64
# 	* kendall correlation = 0.0571841656549013 with a p-value of 6.603192478039498e-66
# length_of_service x awards_won?:
# 	* spearman correlation = -0.03570029655210817 with a p-value of 6.255400781690917e-17
# 	* pearson correlation = -0.03992745036377498 with a p-value of 8.684417583096214e-21
# 	* kendall correlation = -0.0304189700289451 with a p-value of 6.39209112659488e-17
# length_of_service x avg_training_score:
# 	* spearman correlation = -0.028860438613664077 with a p-value of 1.4010078464207294e-11
# 	* pearson correlation = -0.03812215595838487 with a p-value of 4.343255715538472e-19
# 	* kendall correlation = -0.020394817196695558 with a p-value of 1.2628000933546688e-11
# awards_won? x avg_training_score:
# 	* spearman correlation = 0.060718654227859256 with a p-value of 6.16652436037178e-46
# 	* pearson correlation = 0.07213817134361208 with a p-value of 3.797503151043685e-64
# 	* kendall correlation = 0.05023601698640102 with a p-value of 7.418386209912432e-46

# %% [markdown]
# # 2 - Toy Dataset

# %%
from raimitigations.dataprocessing import create_dummy_dataset

df = create_dummy_dataset(
                    samples=3000, 
                    n_features=6, 
                    n_num_num=2, 
                    n_cat_num=2,
                    n_cat_cat=2,
                    num_num_noise=[0.01, 0.05],
                    pct_change=[0.05, 0.1]
                )
label_col = "label"
df
# Out:
#          num_0     num_1     num_2     num_3     num_4     num_5  label  \
# 0    -1.525512  2.875543  2.257682  2.229220  1.594384  2.885251      1
# 1    -2.569836  1.278600  1.688270  3.411097 -0.641013  3.952127      1
# 2    -0.368307  2.262619  0.323905  4.295313  2.963440  2.924983      1
# 3    -3.478053  3.089150  3.671529  1.992963  1.161017  3.281400      1
# 4     1.100563 -0.712498 -3.326899  1.284548  1.673979 -5.369617      0
# ...        ...       ...       ...       ...       ...       ...    ...
# 2995  0.028262  4.294016  1.284022  3.606359  4.288832  1.517827      1
# 2996 -1.736805  1.233513  1.480658  2.275031  0.723627  2.402492      1
# 2997 -2.524129  0.929163  2.538396  0.126336  2.265812  1.555137      1
# 2998 -1.763996  0.636608  2.183026  0.499517  2.560602  1.656918      1
# 2999  1.307582  1.751252 -2.708815  4.187006 -3.927955  1.274081      0
#
#       num_c0_num_0  num_c1_num_1 CN_0_num_0 CN_1_num_1 CC_0_num_0 CC_1_num_1
# 0        -1.532230      2.862426     val0_1     val1_3     val0_2     val1_2
# 1        -2.580926      1.287197     val0_2     val1_2     val0_1     val1_1
# 2        -0.352219      2.264692     val0_2     val1_2     val0_2     val1_2
# 3        -3.462437      3.066536     val0_1     val1_3     val0_1     val1_2
# 4         1.096297     -0.700658     val0_2     val1_1     val0_0     val1_1
# ...            ...           ...        ...        ...        ...        ...
# 2995      0.096331      4.269560     val0_2     val1_3     val0_2     val1_3
# 2996     -1.746102      1.226363     val0_1     val1_2     val0_2     val1_1
# 2997     -2.523848      0.935757     val0_1     val1_2     val0_1     val1_1
# 2998     -1.822879      0.637048     val0_1     val1_1     val0_2     val1_1
# 2999      1.321786      1.709929     val0_2     val1_2     val0_3     val1_2
#
# [3000 rows x 13 columns]

# %% [markdown]
# ## Categorical x Numerical Correlation using the Model approach

# %%
cor_feat = CorrelatedFeatures(
					method_num_num=["spearman", "pearson", "kendall"],
					num_corr_th=0.8,
					num_pvalue_th=0.01,
					method_num_cat="model",
					model_metrics=["f1"],
					metric_th=0.9,
					cat_corr_th=0.8,
					cat_pvalue_th=0.01,
					tie_method="missing",
					json_summary="./corr_json_examples/1_summary_model.json",
					json_corr="./corr_json_examples/1_corr_model.json",
					json_uncorr="./corr_json_examples/1_uncorr_model.json"
				)
cor_feat.fit(df=df, label_col=label_col)
_ = cor_feat.get_summary()
cor_feat.get_selected_features()
# Out:
# CORRELATION SUMMARY
#
# 1 - num_0 x num_c0_num_0:
# 	* spearman correlation = 0.9996753901861544 with a p-value of 0.0
# 	* pearson correlation = 0.9997597612105206 with a p-value of 0.0
# 	* kendall correlation = 0.9851981771701679 with a p-value of 0.0
# 2 - num_0 x CN_0_num_0:
# 	Model metrics:
# 	precision = 0.9390431872868645
# 	recall = 0.9166065542867073
# 	f1 = 0.9273329952270064
# 	auc = 0.9492795862856611
# 	accuracy = 0.9577777777777777
# 3 - num_1 x num_c1_num_1:
# 	* spearman correlation = 0.999818912868768 with a p-value of 0.0
# 	* pearson correlation = 0.9998418004390127 with a p-value of 0.0
# 	* kendall correlation = 0.9888496165388463 with a p-value of 0.0
# 4 - num_1 x CN_1_num_1:
# 	Model metrics:
# 	precision = 0.8901472472787961
# 	recall = 0.9182315949520383
# 	f1 = 0.9030630246432361
# 	auc = 0.9553143997815823
# 	accuracy = 0.9711111111111111
# 5 - num_1 x CC_1_num_1:
# 	Model metrics:
# 	precision = 0.9389101613965745
# 	recall = 0.9372035692679975
# 	f1 = 0.9377419833148879
# 	auc = 0.9649211710562328
# 	accuracy = 0.9822222222222222
# 6 - num_c1_num_1 x CN_1_num_1:
# 	Model metrics:
# 	precision = 0.9303192821056129
# 	recall = 0.9036497188068788
# 	f1 = 0.9159815511755305
# 	auc = 0.945459483501709
# 	accuracy = 0.9588888888888889
# 7 - num_c1_num_1 x CC_1_num_1:
# 	Model metrics:
# 	precision = 0.9518407722202091
# 	recall = 0.948832425892317
# 	f1 = 0.9503132182368355
# 	auc = 0.9700431078732401
# 	accuracy = 0.9788888888888889
#
# NOT CORRELATED VARIABLES SUMMARY
#
# num_0 x num_1:
# 	* spearman correlation = 0.10337839726426634 with a p-value of 1.3859238112162687e-08
# 	* pearson correlation = 0.12494858357335697 with a p-value of 6.520284373846268e-12
# 	* kendall correlation = 0.06940180060020007 with a p-value of 1.2078434311716896e-08
# num_0 x num_2:
# 	* spearman correlation = -0.7726841227426802 with a p-value of 0.0
# 	* pearson correlation = -0.8331704966264728 with a p-value of 0.0
# 	* kendall correlation = -0.5817730354562632 with a p-value of 0.0
# num_0 x num_3:
# 	* spearman correlation = 0.1447435507492834 with a p-value of 1.6308315288860517e-15
# 	* pearson correlation = 0.12358678191217047 with a p-value of 1.1031451013175824e-11
# 	* kendall correlation = 0.09549583194398133 with a p-value of 4.462291324627264e-15
# num_0 x num_4:
# 	* spearman correlation = -0.15796332199592467 with a p-value of 3.2295454389275645e-18
# 	* pearson correlation = -0.376343269711513 with a p-value of 1.4518575564291157e-101
# 	* kendall correlation = -0.06240702456374347 with a p-value of 2.9869115112107524e-07
# num_0 x num_5:
# 	* spearman correlation = -0.17103311278145694 with a p-value of 3.964254959209014e-21
# 	* pearson correlation = -0.3981381088142517 with a p-value of 1.6144345911569423e-114
# 	* kendall correlation = -0.07602889852172946 with a p-value of 4.298897913602809e-10
# num_0 x num_c1_num_1:
# 	* spearman correlation = 0.10306431278492363 with a p-value of 1.533397910561158e-08
# 	* pearson correlation = 0.12465846454855962 with a p-value of 7.296691033626484e-12
# 	* kendall correlation = 0.06918572857619205 with a p-value of 1.3400845076967727e-08
# num_0 x CN_1_num_1:
# 	Model metrics:
# 	precision = 0.2112146849821543
# 	recall = 0.21126770401792722
# 	f1 = 0.21117508117462297
# 	auc = 0.5068758751774395
# 	accuracy = 0.38333333333333336
# num_0 x CC_0_num_0:
# 	Model metrics:
# 	precision = 0.871361273615775
# 	recall = 0.8404181809773619
# 	f1 = 0.8519861290404954
# 	auc = 0.9097010035149211
# 	accuracy = 0.9255555555555556
# num_0 x CC_1_num_1:
# 	Model metrics:
# 	precision = 0.2741035105276106
# 	recall = 0.27312915910465824
# 	f1 = 0.27196652564416407
# 	auc = 0.517209359202675
# 	accuracy = 0.46555555555555556
# num_1 x num_2:
# 	* spearman correlation = 0.12146009438445492 with a p-value of 2.479155494229449e-11
# 	* pearson correlation = 0.11662822845435278 with a p-value of 1.482118743710067e-10
# 	* kendall correlation = 0.08172990996999 with a p-value of 1.9345090375439773e-11
# num_1 x num_3:
# 	* spearman correlation = 0.4360151755572417 with a p-value of 1.7972853652991473e-139
# 	* pearson correlation = 0.4607705324474668 with a p-value of 1.3694221589941792e-157
# 	* kendall correlation = 0.30151650550183395 with a p-value of 2.56361777982999e-135
# num_1 x num_4:
# 	* spearman correlation = 0.18472941208104574 with a p-value of 1.9473487213309194e-24
# 	* pearson correlation = 0.11100077699151498 with a p-value of 1.0870417036362607e-09
# 	* kendall correlation = 0.1256494387017895 with a p-value of 5.895541468719805e-25
# num_1 x num_5:
# 	* spearman correlation = 0.11185621509513499 with a p-value of 8.079835064802033e-10
# 	* pearson correlation = 0.1567975949030991 with a p-value of 5.717614033734425e-18
# 	* kendall correlation = 0.07470223407802601 with a p-value of 8.578463895216783e-10
# num_1 x num_c0_num_0:
# 	* spearman correlation = 0.10335961681773519 with a p-value of 1.3943406332317192e-08
# 	* pearson correlation = 0.1252859189710962 with a p-value of 5.718913540883849e-12
# 	* kendall correlation = 0.06938446148716239 with a p-value of 1.2179695162209155e-08
# num_1 x CN_0_num_0:
# 	Model metrics:
# 	precision = 0.22955042904803272
# 	recall = 0.22993627901400254
# 	f1 = 0.22908467801708016
# 	auc = 0.48646009408215385
# 	accuracy = 0.4066666666666667
# num_1 x CC_0_num_0:
# 	Model metrics:
# 	precision = 0.18701030792831216
# 	recall = 0.18393731354311119
# 	f1 = 0.18528429829788362
# 	auc = 0.48883964909453625
# 	accuracy = 0.28555555555555556
# num_2 x num_3:
# 	* spearman correlation = -0.3604499871611096 with a p-value of 1.0040633643912793e-92
# 	* pearson correlation = -0.2695459004839738 with a p-value of 4.2246702970792246e-51
# 	* kendall correlation = -0.2454324774924975 with a p-value of 2.5545028008839694e-90
# num_2 x num_4:
# 	* spearman correlation = 0.47614039290448806 with a p-value of 1.290576975798064e-169
# 	* pearson correlation = 0.596849757351761 with a p-value of 4.732646371290144e-289
# 	* kendall correlation = 0.31782149605424026 with a p-value of 3.997455885703696e-150
# num_2 x num_5:
# 	* spearman correlation = 0.4196895106321678 with a p-value of 2.5393526815921115e-128
# 	* pearson correlation = 0.6195902587859539 with a p-value of 1.1659307e-317
# 	* kendall correlation = 0.27808691786150935 with a p-value of 2.114793144301531e-115
# num_2 x num_c0_num_0:
# 	* spearman correlation = -0.7726395374043928 with a p-value of 0.0
# 	* pearson correlation = -0.8328718174141726 with a p-value of 0.0
# 	* kendall correlation = -0.5816392130710237 with a p-value of 0.0
# num_2 x num_c1_num_1:
# 	* spearman correlation = 0.12169721796635753 with a p-value of 2.2666899032368493e-11
# 	* pearson correlation = 0.11679532089001747 with a p-value of 1.394910801000201e-10
# 	* kendall correlation = 0.0818597310214516 with a p-value of 1.798112392596339e-11
# num_2 x CN_0_num_0:
# 	Model metrics:
# 	precision = 0.46931404306733704
# 	recall = 0.48447760904777115
# 	f1 = 0.47625242695871556
# 	auc = 0.6553325485600341
# 	accuracy = 0.5844444444444444
# num_2 x CN_1_num_1:
# 	Model metrics:
# 	precision = 0.2001737481801566
# 	recall = 0.20096975252259092
# 	f1 = 0.20053671447393623
# 	auc = 0.5039271132195913
# 	accuracy = 0.38666666666666666
# num_2 x CC_0_num_0:
# 	Model metrics:
# 	precision = 0.38006703545421977
# 	recall = 0.3745451437769714
# 	f1 = 0.3767366658153438
# 	auc = 0.6125850966031489
# 	accuracy = 0.49
# num_2 x CC_1_num_1:
# 	Model metrics:
# 	precision = 0.23832335736304278
# 	recall = 0.2377661826981246
# 	f1 = 0.23773786600855187
# 	auc = 0.4939016837178497
# 	accuracy = 0.4255555555555556
# num_3 x num_4:
# 	* spearman correlation = -0.1733113997012666 with a p-value of 1.1646866015236049e-21
# 	* pearson correlation = -0.14064274417767778 with a p-value of 1.0051560287357476e-14
# 	* kendall correlation = -0.11499788818495053 with a p-value of 3.638773187873958e-21
# num_3 x num_5:
# 	* spearman correlation = 0.18632522114724678 with a p-value of 7.701105001786376e-25
# 	* pearson correlation = 0.19985666379897826 with a p-value of 2.102812300195058e-28
# 	* kendall correlation = 0.12475536289874403 with a p-value of 1.2628112160155834e-24
# num_3 x num_c0_num_0:
# 	* spearman correlation = 0.1446432751825861 with a p-value of 1.7060680161397377e-15
# 	* pearson correlation = 0.12394756878450391 with a p-value of 9.602240057844404e-12
# 	* kendall correlation = 0.09547315771923975 with a p-value of 4.5289478467146586e-15
# num_3 x num_c1_num_1:
# 	* spearman correlation = 0.43603951155994564 with a p-value of 1.7279600723595427e-139
# 	* pearson correlation = 0.4606856261600652 with a p-value of 1.589554007186428e-157
# 	* kendall correlation = 0.30148627320217847 with a p-value of 2.726379326492916e-135
# num_3 x CN_0_num_0:
# 	Model metrics:
# 	precision = 0.25424247417378637
# 	recall = 0.25638264543384676
# 	f1 = 0.254635704832684
# 	auc = 0.5005843723919888
# 	accuracy = 0.4088888888888889
# num_3 x CN_1_num_1:
# 	Model metrics:
# 	precision = 0.23195340848326335
# 	recall = 0.23604762561304554
# 	f1 = 0.2334776790201793
# 	auc = 0.522087854038736
# 	accuracy = 0.3877777777777778
# num_3 x CC_0_num_0:
# 	Model metrics:
# 	precision = 0.229053521780659
# 	recall = 0.22570297156363
# 	f1 = 0.22701767193194605
# 	auc = 0.5141597736916809
# 	accuracy = 0.3277777777777778
# num_3 x CC_1_num_1:
# 	Model metrics:
# 	precision = 0.2805947841148779
# 	recall = 0.27978675136116155
# 	f1 = 0.2799659569279313
# 	auc = 0.5208454491047046
# 	accuracy = 0.46444444444444444
# num_4 x num_5:
# 	* spearman correlation = 0.43106282034031324 with a p-value of 5.036325624329036e-136
# 	* pearson correlation = 0.49961961889722173 with a p-value of 3.244991892278831e-189
# 	* kendall correlation = 0.2825684116927865 with a p-value of 4.363698569255595e-119
# num_4 x num_c0_num_0:
# 	* spearman correlation = -0.15755086995009665 with a p-value of 3.954840658593824e-18
# 	* pearson correlation = -0.3757902824298459 with a p-value of 3.005579747606378e-101
# 	* kendall correlation = -0.06203045459597644 with a p-value of 3.5179020886435283e-07
# num_4 x num_c1_num_1:
# 	* spearman correlation = 0.18476148764016526 with a p-value of 1.9115321009389032e-24
# 	* pearson correlation = 0.11121125616280406 with a p-value of 1.0107275134762999e-09
# 	* kendall correlation = 0.12560142269645438 with a p-value of 6.142553150230272e-25
# num_4 x CN_0_num_0:
# 	Model metrics:
# 	precision = 0.34633030332987746
# 	recall = 0.35383037852390115
# 	f1 = 0.3493989760736177
# 	auc = 0.5762873153257824
# 	accuracy = 0.5066666666666667
# num_4 x CN_1_num_1:
# 	Model metrics:
# 	precision = 0.19523234799937478
# 	recall = 0.1936475038130004
# 	f1 = 0.19443667766866884
# 	auc = 0.4967689833485366
# 	accuracy = 0.3688888888888889
# num_4 x CC_0_num_0:
# 	Model metrics:
# 	precision = 0.2869639343441769
# 	recall = 0.2877949839065916
# 	f1 = 0.2872035413085012
# 	auc = 0.5586343045193485
# 	accuracy = 0.4066666666666667
# num_4 x CC_1_num_1:
# 	Model metrics:
# 	precision = 0.2886430027483028
# 	recall = 0.28393224440411374
# 	f1 = 0.28559938522840683
# 	auc = 0.5242158276772196
# 	accuracy = 0.47333333333333333
# num_5 x num_c0_num_0:
# 	* spearman correlation = -0.17105526611725175 with a p-value of 3.917637639611096e-21
# 	* pearson correlation = -0.3975613968065966 with a p-value of 3.660715114332925e-114
# 	* kendall correlation = -0.07606579971101478 with a p-value of 4.216374418694979e-10
# num_5 x num_c1_num_1:
# 	* spearman correlation = 0.11232963470329274 with a p-value of 6.849858966824802e-10
# 	* pearson correlation = 0.15696982186083674 with a p-value of 5.25632925726924e-18
# 	* kendall correlation = 0.07499210848060464 with a p-value of 7.383774950981439e-10
# num_5 x CN_0_num_0:
# 	Model metrics:
# 	precision = 0.36174213110027176
# 	recall = 0.3615883557261377
# 	f1 = 0.3614020900404075
# 	auc = 0.5770662440130905
# 	accuracy = 0.5066666666666667
# num_5 x CN_1_num_1:
# 	Model metrics:
# 	precision = 0.1988173456325798
# 	recall = 0.19894064550015494
# 	f1 = 0.19861271808711728
# 	auc = 0.5006074124208466
# 	accuracy = 0.36666666666666664
# num_5 x CC_0_num_0:
# 	Model metrics:
# 	precision = 0.2825275029762496
# 	recall = 0.2857901374564415
# 	f1 = 0.2838195041839828
# 	auc = 0.5542172824993445
# 	accuracy = 0.3888888888888889
# num_5 x CC_1_num_1:
# 	Model metrics:
# 	precision = 0.24411521332270475
# 	recall = 0.2461796733212341
# 	f1 = 0.2451129804718415
# 	auc = 0.5005521494341985
# 	accuracy = 0.4477777777777778
# num_c0_num_0 x num_c1_num_1:
# 	* spearman correlation = 0.10306309011812112 with a p-value of 1.5340007389363042e-08
# 	* pearson correlation = 0.125003458131239 with a p-value of 6.38281624495451e-12
# 	* kendall correlation = 0.0691621651661665 with a p-value of 1.3553292136441584e-08
# num_c0_num_0 x CN_0_num_0:
# 	Model metrics:
# 	precision = 0.9043967372936343
# 	recall = 0.8925314005124603
# 	f1 = 0.8979755574929212
# 	auc = 0.9335557170791047
# 	accuracy = 0.9377777777777778
# num_c0_num_0 x CN_1_num_1:
# 	Model metrics:
# 	precision = 0.18546191097038553
# 	recall = 0.18829628023611802
# 	f1 = 0.18686331479639715
# 	auc = 0.4947828889659167
# 	accuracy = 0.37777777777777777
# num_c0_num_0 x CC_0_num_0:
# 	Model metrics:
# 	precision = 0.8088274450910504
# 	recall = 0.7887311772053541
# 	f1 = 0.7980831496860834
# 	auc = 0.8789914103956009
# 	accuracy = 0.89
# num_c0_num_0 x CC_1_num_1:
# 	Model metrics:
# 	precision = 0.2646128631453127
# 	recall = 0.26132335148215363
# 	f1 = 0.262540554846806
# 	auc = 0.5073648034462285
# 	accuracy = 0.44333333333333336
# num_c1_num_1 x CN_0_num_0:
# 	Model metrics:
# 	precision = 0.24371906918704073
# 	recall = 0.24216393321467503
# 	f1 = 0.24234906701349632
# 	auc = 0.4925240586652916
# 	accuracy = 0.39666666666666667
# num_c1_num_1 x CC_0_num_0:
# 	Model metrics:
# 	precision = 0.2073747076511861
# 	recall = 0.20868307242844467
# 	f1 = 0.20789930365388765
# 	auc = 0.5042271761884962
# 	accuracy = 0.30666666666666664
# CN_0_num_0 x CN_1_num_1:
# 	* Cramer's V = 0.0873 with a p-value of 0.0
# CN_0_num_0 x CC_0_num_0:
# 	* Cramer's V = 0.6074 with a p-value of 0.0
# CN_0_num_0 x CC_1_num_1:
# 	* Cramer's V = 0.0853 with a p-value of 0.0
# CN_1_num_1 x CC_0_num_0:
# 	* Cramer's V = 0.0862 with a p-value of 0.0
# CN_1_num_1 x CC_1_num_1:
# 	* Cramer's V = 0.6001 with a p-value of 0.0
# CC_0_num_0 x CC_1_num_1:
# 	* Cramer's V = 0.0928 with a p-value of 0.0
# ['num_2',
#  'num_3',
#  'num_4',
#  'num_5',
#  'num_c0_num_0',
#  'CN_0_num_0',
#  'CN_1_num_1',
#  'CC_0_num_0',
#  'CC_1_num_1']

# %% [markdown]
# ## Categorical x Numerical Correlation using the Jensen approach

# %%
cor_feat = CorrelatedFeatures(
					method_num_num=["kendall"],
					num_corr_th=0.8,
					num_pvalue_th=0.01,
					method_num_cat="jensen",
					jensen_n_bins=200,
					jensen_th=0.9,
					tie_method="var",
					json_summary="./corr_json_examples/2_summary_jensen.json",
					json_corr="./corr_json_examples/2_corr_jensen.json",
					json_uncorr="./corr_json_examples/2_uncorr_jensen.json"
				)
cor_feat.fit(df=df, label_col=label_col)
_ = cor_feat.get_summary()
cor_feat.get_selected_features()
# Out:
# CORRELATION SUMMARY
#
# 1 - num_0 x num_c0_num_0:
# 	* kendall correlation = 0.9851981771701679 with a p-value of 0.0
# 2 - num_0 x CN_0_num_0:
# 	Jensen-Shannon results:
# 	jensen val0_1 x val0_2 = 0.9752599874257479
# 	jensen val0_1 x val0_3 = 0.9308744294656628
# 	jensen val0_1 x val0_0 = 0.9094893510593968
# 	jensen val0_2 x val0_3 = 0.9655643222237329
# 	jensen val0_2 x val0_0 = 0.9581523012900924
# 	jensen val0_3 x val0_0 = 0.9663876399222759
# 3 - num_1 x num_c1_num_1:
# 	* kendall correlation = 0.9888496165388463 with a p-value of 0.0
# 4 - num_1 x CC_1_num_1:
# 	Jensen-Shannon results:
# 	jensen val1_2 x val1_1 = 0.9929982619772626
# 	jensen val1_2 x val1_0 = 0.9581764256258682
# 	jensen val1_2 x val1_3 = 0.9805283754190949
# 	jensen val1_1 x val1_0 = 0.9474890759069279
# 	jensen val1_1 x val1_3 = 0.9851998562127596
# 	jensen val1_0 x val1_3 = 0.982841358269058
# 5 - num_c1_num_1 x CC_1_num_1:
# 	Jensen-Shannon results:
# 	jensen val1_2 x val1_1 = 0.983292600101525
# 	jensen val1_2 x val1_0 = 0.9523441810386128
# 	jensen val1_2 x val1_3 = 0.9748764029233492
# 	jensen val1_1 x val1_0 = 0.9390880399718561
# 	jensen val1_1 x val1_3 = 0.9833127291637477
# 	jensen val1_0 x val1_3 = 0.978520546597722
#
# NOT CORRELATED VARIABLES SUMMARY
#
# num_0 x num_1:
# 	* kendall correlation = 0.06940180060020007 with a p-value of 1.2078434311716896e-08
# num_0 x num_2:
# 	* kendall correlation = -0.5817730354562632 with a p-value of 0.0
# num_0 x num_3:
# 	* kendall correlation = 0.09549583194398133 with a p-value of 4.462291324627264e-15
# num_0 x num_4:
# 	* kendall correlation = -0.06240702456374347 with a p-value of 2.9869115112107524e-07
# num_0 x num_5:
# 	* kendall correlation = -0.07602889852172946 with a p-value of 4.298897913602809e-10
# num_0 x num_c1_num_1:
# 	* kendall correlation = 0.06918572857619205 with a p-value of 1.3400845076967727e-08
# num_0 x CN_1_num_1:
# 	Jensen-Shannon results:
# 	jensen val1_3 x val1_2 = 0.2979591702312014
# 	jensen val1_3 x val1_1 = 0.36547735690867356
# 	jensen val1_3 x val1_0 = 0.7467398511117487
# 	jensen val1_3 x val1_4 = 0.5988413236305028
# 	jensen val1_2 x val1_1 = 0.30664166147769173
# 	jensen val1_2 x val1_0 = 0.7444919404447201
# 	jensen val1_2 x val1_4 = 0.6141453737571355
# 	jensen val1_1 x val1_0 = 0.7234495901098486
# 	jensen val1_1 x val1_4 = 0.6506548663609505
# 	jensen val1_0 x val1_4 = 0.8345535338117005
# num_0 x CC_0_num_0:
# 	Jensen-Shannon results:
# 	jensen val0_2 x val0_1 = 0.9693645947685644
# 	jensen val0_2 x val0_0 = 0.8816926529129224
# 	jensen val0_2 x val0_4 = 0.9105831994373285
# 	jensen val0_2 x val0_3 = 0.945623383270486
# 	jensen val0_1 x val0_0 = 0.8917403671706358
# 	jensen val0_1 x val0_4 = 0.9434871956995649
# 	jensen val0_1 x val0_3 = 0.9661044204683901
# 	jensen val0_0 x val0_4 = 0.9536806834953089
# 	jensen val0_0 x val0_3 = 0.9677971014358494
# 	jensen val0_4 x val0_3 = 0.9665793550728325
# num_0 x CC_1_num_1:
# 	Jensen-Shannon results:
# 	jensen val1_2 x val1_1 = 0.23982667118914022
# 	jensen val1_2 x val1_0 = 0.6603804823971203
# 	jensen val1_2 x val1_3 = 0.49324307231021286
# 	jensen val1_1 x val1_0 = 0.6488232811794798
# 	jensen val1_1 x val1_3 = 0.5146973436621548
# 	jensen val1_0 x val1_3 = 0.7402447519705077
# num_1 x num_2:
# 	* kendall correlation = 0.08172990996999 with a p-value of 1.9345090375439773e-11
# num_1 x num_3:
# 	* kendall correlation = 0.30151650550183395 with a p-value of 2.56361777982999e-135
# num_1 x num_4:
# 	* kendall correlation = 0.1256494387017895 with a p-value of 5.895541468719805e-25
# num_1 x num_5:
# 	* kendall correlation = 0.07470223407802601 with a p-value of 8.578463895216783e-10
# num_1 x num_c0_num_0:
# 	* kendall correlation = 0.06938446148716239 with a p-value of 1.2179695162209155e-08
# num_1 x CN_0_num_0:
# 	Jensen-Shannon results:
# 	jensen val0_1 x val0_2 = 0.2304091210065694
# 	jensen val0_1 x val0_3 = 0.4214404399879243
# 	jensen val0_1 x val0_0 = 0.39789281969041684
# 	jensen val0_2 x val0_3 = 0.44211115423699676
# 	jensen val0_2 x val0_0 = 0.4270421547185273
# 	jensen val0_3 x val0_0 = 0.5679559914168147
# num_1 x CN_1_num_1:
# 	Jensen-Shannon results:
# 	jensen val1_3 x val1_2 = 0.9910337033269477
# 	jensen val1_3 x val1_1 = 0.9941369709804782
# 	jensen val1_3 x val1_0 = 0.966496899793273
# 	jensen val1_3 x val1_4 = 0.9794902803020958
# 	jensen val1_2 x val1_1 = 0.9758098769418071
# 	jensen val1_2 x val1_0 = 0.9424102459026586
# 	jensen val1_2 x val1_4 = 0.8946644007717108
# 	jensen val1_1 x val1_0 = 0.962032652582279
# 	jensen val1_1 x val1_4 = 0.989241733928721
# 	jensen val1_0 x val1_4 = 0.985105857247795
# num_1 x CC_0_num_0:
# 	Jensen-Shannon results:
# 	jensen val0_2 x val0_1 = 0.23317492244566354
# 	jensen val0_2 x val0_0 = 0.536617668091636
# 	jensen val0_2 x val0_4 = 0.47985870338141734
# 	jensen val0_2 x val0_3 = 0.3142956095798287
# 	jensen val0_1 x val0_0 = 0.5322829895092704
# 	jensen val0_1 x val0_4 = 0.5189602797629898
# 	jensen val0_1 x val0_3 = 0.29802018826413756
# 	jensen val0_0 x val0_4 = 0.7219275036961563
# 	jensen val0_0 x val0_3 = 0.5822777671438605
# 	jensen val0_4 x val0_3 = 0.5109806922022558
# num_2 x num_3:
# 	* kendall correlation = -0.2454324774924975 with a p-value of 2.5545028008839694e-90
# num_2 x num_4:
# 	* kendall correlation = 0.31782149605424026 with a p-value of 3.997455885703696e-150
# num_2 x num_5:
# 	* kendall correlation = 0.27808691786150935 with a p-value of 2.114793144301531e-115
# num_2 x num_c0_num_0:
# 	* kendall correlation = -0.5816392130710237 with a p-value of 0.0
# num_2 x num_c1_num_1:
# 	* kendall correlation = 0.0818597310214516 with a p-value of 1.798112392596339e-11
# num_2 x CN_0_num_0:
# 	Jensen-Shannon results:
# 	jensen val0_1 x val0_2 = 0.6059703864647777
# 	jensen val0_1 x val0_3 = 0.9045252713749633
# 	jensen val0_1 x val0_0 = 0.48473858065888464
# 	jensen val0_2 x val0_3 = 0.686973916827324
# 	jensen val0_2 x val0_0 = 0.7911338077429434
# 	jensen val0_3 x val0_0 = 0.913861136103071
# num_2 x CN_1_num_1:
# 	Jensen-Shannon results:
# 	jensen val1_3 x val1_2 = 0.2863227646626017
# 	jensen val1_3 x val1_1 = 0.3722440223730061
# 	jensen val1_3 x val1_0 = 0.7774499462488638
# 	jensen val1_3 x val1_4 = 0.5626361582267502
# 	jensen val1_2 x val1_1 = 0.3128503144901819
# 	jensen val1_2 x val1_0 = 0.770680344788357
# 	jensen val1_2 x val1_4 = 0.5666842977444168
# 	jensen val1_1 x val1_0 = 0.7767579657656621
# 	jensen val1_1 x val1_4 = 0.6275830321508359
# 	jensen val1_0 x val1_4 = 0.8267351970166246
# num_2 x CC_0_num_0:
# 	Jensen-Shannon results:
# 	jensen val0_2 x val0_1 = 0.4562821064169838
# 	jensen val0_2 x val0_0 = 0.6488644777508956
# 	jensen val0_2 x val0_4 = 0.8482267626249137
# 	jensen val0_2 x val0_3 = 0.7079621448995533
# 	jensen val0_1 x val0_0 = 0.46544134813463905
# 	jensen val0_1 x val0_4 = 0.8910363151027666
# 	jensen val0_1 x val0_3 = 0.8460263147893444
# 	jensen val0_0 x val0_4 = 0.9224583364089155
# 	jensen val0_0 x val0_3 = 0.867964068125392
# 	jensen val0_4 x val0_3 = 0.5866340200541964
# num_2 x CC_1_num_1:
# 	Jensen-Shannon results:
# 	jensen val1_2 x val1_1 = 0.23989183671010253
# 	jensen val1_2 x val1_0 = 0.6702487291798562
# 	jensen val1_2 x val1_3 = 0.40033611216363313
# 	jensen val1_1 x val1_0 = 0.6546502759193064
# 	jensen val1_1 x val1_3 = 0.4387389018196516
# 	jensen val1_0 x val1_3 = 0.7455879770404115
# num_3 x num_4:
# 	* kendall correlation = -0.11499788818495053 with a p-value of 3.638773187873958e-21
# num_3 x num_5:
# 	* kendall correlation = 0.12475536289874403 with a p-value of 1.2628112160155834e-24
# num_3 x num_c0_num_0:
# 	* kendall correlation = 0.09547315771923975 with a p-value of 4.5289478467146586e-15
# num_3 x num_c1_num_1:
# 	* kendall correlation = 0.30148627320217847 with a p-value of 2.726379326492916e-135
# num_3 x CN_0_num_0:
# 	Jensen-Shannon results:
# 	jensen val0_1 x val0_2 = 0.2427919508317038
# 	jensen val0_1 x val0_3 = 0.3513254704286019
# 	jensen val0_1 x val0_0 = 0.4295236776519446
# 	jensen val0_2 x val0_3 = 0.3526228828996837
# 	jensen val0_2 x val0_0 = 0.45931859288075366
# 	jensen val0_3 x val0_0 = 0.5048852173680172
# num_3 x CN_1_num_1:
# 	Jensen-Shannon results:
# 	jensen val1_3 x val1_2 = 0.32772263980412486
# 	jensen val1_3 x val1_1 = 0.529952965625677
# 	jensen val1_3 x val1_0 = 0.7826263491347873
# 	jensen val1_3 x val1_4 = 0.5520409179011003
# 	jensen val1_2 x val1_1 = 0.36394511647988564
# 	jensen val1_2 x val1_0 = 0.7540998558345253
# 	jensen val1_2 x val1_4 = 0.6237565951792035
# 	jensen val1_1 x val1_0 = 0.7675865589919192
# 	jensen val1_1 x val1_4 = 0.739976347271842
# 	jensen val1_0 x val1_4 = 0.8396416680061661
# num_3 x CC_0_num_0:
# 	Jensen-Shannon results:
# 	jensen val0_2 x val0_1 = 0.26164467458224383
# 	jensen val0_2 x val0_0 = 0.5701409476003808
# 	jensen val0_2 x val0_4 = 0.45807696576227724
# 	jensen val0_2 x val0_3 = 0.28428630365033003
# 	jensen val0_1 x val0_0 = 0.5476256856654435
# 	jensen val0_1 x val0_4 = 0.48455126927105463
# 	jensen val0_1 x val0_3 = 0.3203273059527504
# 	jensen val0_0 x val0_4 = 0.6661276733462247
# 	jensen val0_0 x val0_3 = 0.5915644414856525
# 	jensen val0_4 x val0_3 = 0.4562005804085773
# num_3 x CC_1_num_1:
# 	Jensen-Shannon results:
# 	jensen val1_2 x val1_1 = 0.34134148521548013
# 	jensen val1_2 x val1_0 = 0.7214828765943174
# 	jensen val1_2 x val1_3 = 0.4615124554339223
# 	jensen val1_1 x val1_0 = 0.6590369062449766
# 	jensen val1_1 x val1_3 = 0.6116014218707754
# 	jensen val1_0 x val1_3 = 0.8185589014182125
# num_4 x num_5:
# 	* kendall correlation = 0.2825684116927865 with a p-value of 4.363698569255595e-119
# num_4 x num_c0_num_0:
# 	* kendall correlation = -0.06203045459597644 with a p-value of 3.5179020886435283e-07
# num_4 x num_c1_num_1:
# 	* kendall correlation = 0.12560142269645438 with a p-value of 6.142553150230272e-25
# num_4 x CN_0_num_0:
# 	Jensen-Shannon results:
# 	jensen val0_1 x val0_2 = 0.4815751796818459
# 	jensen val0_1 x val0_3 = 0.7718372801557156
# 	jensen val0_1 x val0_0 = 0.45944004125340143
# 	jensen val0_2 x val0_3 = 0.5784689963181981
# 	jensen val0_2 x val0_0 = 0.6432295273801789
# 	jensen val0_3 x val0_0 = 0.7063874795232173
# num_4 x CN_1_num_1:
# 	Jensen-Shannon results:
# 	jensen val1_3 x val1_2 = 0.28876363711668523
# 	jensen val1_3 x val1_1 = 0.4123531429719582
# 	jensen val1_3 x val1_0 = 0.758010806068616
# 	jensen val1_3 x val1_4 = 0.5365802026333093
# 	jensen val1_2 x val1_1 = 0.3004219974993187
# 	jensen val1_2 x val1_0 = 0.7266320505606704
# 	jensen val1_2 x val1_4 = 0.5610260175003567
# 	jensen val1_1 x val1_0 = 0.7129170576650649
# 	jensen val1_1 x val1_4 = 0.6237342280444181
# 	jensen val1_0 x val1_4 = 0.8726989479865132
# num_4 x CC_0_num_0:
# 	Jensen-Shannon results:
# 	jensen val0_2 x val0_1 = 0.3593247526028582
# 	jensen val0_2 x val0_0 = 0.6501208394411945
# 	jensen val0_2 x val0_4 = 0.7090988154594889
# 	jensen val0_2 x val0_3 = 0.6270157746277867
# 	jensen val0_1 x val0_0 = 0.5119737718327435
# 	jensen val0_1 x val0_4 = 0.7074459405969787
# 	jensen val0_1 x val0_3 = 0.6701185370472298
# 	jensen val0_0 x val0_4 = 0.730754497971177
# 	jensen val0_0 x val0_3 = 0.7221420643562716
# 	jensen val0_4 x val0_3 = 0.5378763936250155
# num_4 x CC_1_num_1:
# 	Jensen-Shannon results:
# 	jensen val1_2 x val1_1 = 0.2691682346341381
# 	jensen val1_2 x val1_0 = 0.6608025770924173
# 	jensen val1_2 x val1_3 = 0.45679162270536344
# 	jensen val1_1 x val1_0 = 0.6123730764008961
# 	jensen val1_1 x val1_3 = 0.5385613930311242
# 	jensen val1_0 x val1_3 = 0.7999135267520037
# num_5 x num_c0_num_0:
# 	* kendall correlation = -0.07606579971101478 with a p-value of 4.216374418694979e-10
# num_5 x num_c1_num_1:
# 	* kendall correlation = 0.07499210848060464 with a p-value of 7.383774950981439e-10
# num_5 x CN_0_num_0:
# 	Jensen-Shannon results:
# 	jensen val0_1 x val0_2 = 0.5049390342037575
# 	jensen val0_1 x val0_3 = 0.8018308236562217
# 	jensen val0_1 x val0_0 = 0.4770926603502919
# 	jensen val0_2 x val0_3 = 0.6124383816273327
# 	jensen val0_2 x val0_0 = 0.660603799696456
# 	jensen val0_3 x val0_0 = 0.7511150129731746
# num_5 x CN_1_num_1:
# 	Jensen-Shannon results:
# 	jensen val1_3 x val1_2 = 0.2588190085324838
# 	jensen val1_3 x val1_1 = 0.3744039843632633
# 	jensen val1_3 x val1_0 = 0.8084989618930949
# 	jensen val1_3 x val1_4 = 0.537618512231857
# 	jensen val1_2 x val1_1 = 0.3480497332437548
# 	jensen val1_2 x val1_0 = 0.7876249147190683
# 	jensen val1_2 x val1_4 = 0.5512529690418333
# 	jensen val1_1 x val1_0 = 0.7827938987224417
# 	jensen val1_1 x val1_4 = 0.5900946102749385
# 	jensen val1_0 x val1_4 = 0.8087393693136696
# num_5 x CC_0_num_0:
# 	Jensen-Shannon results:
# 	jensen val0_2 x val0_1 = 0.33878874496409633
# 	jensen val0_2 x val0_0 = 0.6324816243891932
# 	jensen val0_2 x val0_4 = 0.7931522435147134
# 	jensen val0_2 x val0_3 = 0.6481228520993524
# 	jensen val0_1 x val0_0 = 0.5400319165327724
# 	jensen val0_1 x val0_4 = 0.7668814664878946
# 	jensen val0_1 x val0_3 = 0.6776765034061306
# 	jensen val0_0 x val0_4 = 0.802295010159283
# 	jensen val0_0 x val0_3 = 0.7244251253974894
# 	jensen val0_4 x val0_3 = 0.517761859974035
# num_5 x CC_1_num_1:
# 	Jensen-Shannon results:
# 	jensen val1_2 x val1_1 = 0.25590882168401735
# 	jensen val1_2 x val1_0 = 0.6925671130888912
# 	jensen val1_2 x val1_3 = 0.43846949442451694
# 	jensen val1_1 x val1_0 = 0.6808586016940047
# 	jensen val1_1 x val1_3 = 0.46827149833770376
# 	jensen val1_0 x val1_3 = 0.7177985229837164
# num_c0_num_0 x num_c1_num_1:
# 	* kendall correlation = 0.0691621651661665 with a p-value of 1.3553292136441584e-08
# num_c0_num_0 x CN_0_num_0:
# 	Jensen-Shannon results:
# 	jensen val0_1 x val0_2 = 0.9648819588397385
# 	jensen val0_1 x val0_3 = 0.9333939562030074
# 	jensen val0_1 x val0_0 = 0.8987424295606912
# 	jensen val0_2 x val0_3 = 0.9545862836185455
# 	jensen val0_2 x val0_0 = 0.9569667978725048
# 	jensen val0_3 x val0_0 = 0.977647755563439
# num_c0_num_0 x CN_1_num_1:
# 	Jensen-Shannon results:
# 	jensen val1_3 x val1_2 = 0.2835475326807595
# 	jensen val1_3 x val1_1 = 0.38624676105141637
# 	jensen val1_3 x val1_0 = 0.7478515230571485
# 	jensen val1_3 x val1_4 = 0.6098264206448623
# 	jensen val1_2 x val1_1 = 0.30694222588217024
# 	jensen val1_2 x val1_0 = 0.7436792215628578
# 	jensen val1_2 x val1_4 = 0.6197451684495277
# 	jensen val1_1 x val1_0 = 0.7485119368159184
# 	jensen val1_1 x val1_4 = 0.6557321495935148
# 	jensen val1_0 x val1_4 = 0.8515573538987858
# num_c0_num_0 x CC_0_num_0:
# 	Jensen-Shannon results:
# 	jensen val0_2 x val0_1 = 0.9516487474829325
# 	jensen val0_2 x val0_0 = 0.8704925583970692
# 	jensen val0_2 x val0_4 = 0.9106701678560238
# 	jensen val0_2 x val0_3 = 0.9392581370237991
# 	jensen val0_1 x val0_0 = 0.8802531969490274
# 	jensen val0_1 x val0_4 = 0.946179821266479
# 	jensen val0_1 x val0_3 = 0.9631633632756307
# 	jensen val0_0 x val0_4 = 0.9522031085926463
# 	jensen val0_0 x val0_3 = 0.9573708220748787
# 	jensen val0_4 x val0_3 = 0.9542420504349987
# num_c0_num_0 x CC_1_num_1:
# 	Jensen-Shannon results:
# 	jensen val1_2 x val1_1 = 0.2402028605667742
# 	jensen val1_2 x val1_0 = 0.6366941782063023
# 	jensen val1_2 x val1_3 = 0.47169332413521126
# 	jensen val1_1 x val1_0 = 0.6432022523073836
# 	jensen val1_1 x val1_3 = 0.5037283388612916
# 	jensen val1_0 x val1_3 = 0.7264641879234056
# num_c1_num_1 x CN_0_num_0:
# 	Jensen-Shannon results:
# 	jensen val0_1 x val0_2 = 0.22971898059418222
# 	jensen val0_1 x val0_3 = 0.4010862489014438
# 	jensen val0_1 x val0_0 = 0.4139805905236644
# 	jensen val0_2 x val0_3 = 0.4341076436247383
# 	jensen val0_2 x val0_0 = 0.42972295012488054
# 	jensen val0_3 x val0_0 = 0.5398749623014055
# num_c1_num_1 x CN_1_num_1:
# 	Jensen-Shannon results:
# 	jensen val1_3 x val1_2 = 0.9802269872629069
# 	jensen val1_3 x val1_1 = 0.9944688479623199
# 	jensen val1_3 x val1_0 = 0.9550952323587764
# 	jensen val1_3 x val1_4 = 0.9747442565326766
# 	jensen val1_2 x val1_1 = 0.9693709247403375
# 	jensen val1_2 x val1_0 = 0.9436567004580523
# 	jensen val1_2 x val1_4 = 0.8979762924843571
# 	jensen val1_1 x val1_0 = 0.9617460804126483
# 	jensen val1_1 x val1_4 = 0.9904546890530055
# 	jensen val1_0 x val1_4 = 0.9699830410722786
# num_c1_num_1 x CC_0_num_0:
# 	Jensen-Shannon results:
# 	jensen val0_2 x val0_1 = 0.25066988873692503
# 	jensen val0_2 x val0_0 = 0.49451088601498705
# 	jensen val0_2 x val0_4 = 0.49662901333176396
# 	jensen val0_2 x val0_3 = 0.31392833014646654
# 	jensen val0_1 x val0_0 = 0.47979990080464985
# 	jensen val0_1 x val0_4 = 0.5213545526751758
# 	jensen val0_1 x val0_3 = 0.30715549482032833
# 	jensen val0_0 x val0_4 = 0.6902787381051191
# 	jensen val0_0 x val0_3 = 0.5262341494703897
# 	jensen val0_4 x val0_3 = 0.5393840154607438
# CN_0_num_0 x CN_1_num_1:
# 	* Cramer's V = 0.0873 with a p-value of 0.0
# CN_0_num_0 x CC_0_num_0:
# 	* Cramer's V = 0.6074 with a p-value of 0.0
# CN_0_num_0 x CC_1_num_1:
# 	* Cramer's V = 0.0853 with a p-value of 0.0
# CN_1_num_1 x CC_0_num_0:
# 	* Cramer's V = 0.0862 with a p-value of 0.0
# CN_1_num_1 x CC_1_num_1:
# 	* Cramer's V = 0.6001 with a p-value of 0.0
# CC_0_num_0 x CC_1_num_1:
# 	* Cramer's V = 0.0928 with a p-value of 0.0
# ['num_2',
#  'num_3',
#  'num_4',
#  'num_5',
#  'num_c0_num_0',
#  'num_c1_num_1',
#  'CN_0_num_0',
#  'CN_1_num_1',
#  'CC_0_num_0']

# %% [markdown]
# ## Categorical x Numerical Correlation using the ANOVA approach

# %%
cor_feat = CorrelatedFeatures(
					method_num_num=["kendall"],
					num_corr_th=0.8,
					num_pvalue_th=0.01,
					method_num_cat="anova",
					levene_pvalue=0.01,
					anova_pvalue=0.05,
					omega_th=0.75,
					tie_method="cardinality",
					json_summary="./corr_json_examples/3_summary_anova.json",
					json_corr="./corr_json_examples/3_corr_anova.json",
					json_uncorr="./corr_json_examples/3_uncorr_anova.json"
				)
cor_feat.fit(df=df, label_col=label_col)
_ = cor_feat.get_summary()
cor_feat.get_selected_features()
# Out:
# CORRELATION SUMMARY
#
# 1 - num_0 x num_c0_num_0:
# 	* kendall correlation = 0.9851981771701679 with a p-value of 0.0
# 2 - num_1 x num_c1_num_1:
# 	* kendall correlation = 0.9888496165388463 with a p-value of 0.0
#
# NOT CORRELATED VARIABLES SUMMARY
#
# num_0 x num_1:
# 	* kendall correlation = 0.06940180060020007 with a p-value of 1.2078434311716896e-08
# num_0 x num_2:
# 	* kendall correlation = -0.5817730354562632 with a p-value of 0.0
# num_0 x num_3:
# 	* kendall correlation = 0.09549583194398133 with a p-value of 4.462291324627264e-15
# num_0 x num_4:
# 	* kendall correlation = -0.06240702456374347 with a p-value of 2.9869115112107524e-07
# num_0 x num_5:
# 	* kendall correlation = -0.07602889852172946 with a p-value of 4.298897913602809e-10
# num_0 x num_c1_num_1:
# 	* kendall correlation = 0.06918572857619205 with a p-value of 1.3400845076967727e-08
# num_0 x CN_0_num_0:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 1.1298738572415836e-08
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 2859.347564606845
# 	P-Value for the ANOVA F-Value = 0.0
# 	Omega Squared = 0.7408216903077529
# num_0 x CN_1_num_1:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 0.0031588790900623862
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 10.993941947828475
# 	P-Value for the ANOVA F-Value = 7.510283610898303e-09
# 	Omega Squared = 0.013150028436035258
# num_0 x CC_0_num_0:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 1.060559812454213e-50
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 2397.6032699670754
# 	P-Value for the ANOVA F-Value = 0.0
# 	Omega Squared = 0.7616477402288316
# num_0 x CC_1_num_1:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 0.002839851537405295
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 14.377498811582297
# 	P-Value for the ANOVA F-Value = 2.671521241639869e-09
# 	Omega Squared = 0.013200903737521787
# num_1 x num_2:
# 	* kendall correlation = 0.08172990996999 with a p-value of 1.9345090375439773e-11
# num_1 x num_3:
# 	* kendall correlation = 0.30151650550183395 with a p-value of 2.56361777982999e-135
# num_1 x num_4:
# 	* kendall correlation = 0.1256494387017895 with a p-value of 5.895541468719805e-25
# num_1 x num_5:
# 	* kendall correlation = 0.07470223407802601 with a p-value of 8.578463895216783e-10
# num_1 x num_c0_num_0:
# 	* kendall correlation = 0.06938446148716239 with a p-value of 1.2179695162209155e-08
# num_1 x CN_0_num_0:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 0.22008567156426506
# 	Valid Anova (Homoscedasticity data)?: True
# 	ANOVA F-Value = 20.900438706155665
# 	P-Value for the ANOVA F-Value = 2.128394173908494e-13
# 	Omega Squared = 0.01951213858815605
# num_1 x CN_1_num_1:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 1.6911679184518741e-49
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 2616.414850997723
# 	P-Value for the ANOVA F-Value = 0.0
# 	Omega Squared = 0.7771448593395099
# num_1 x CC_0_num_0:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 0.3462920995424337
# 	Valid Anova (Homoscedasticity data)?: True
# 	ANOVA F-Value = 19.825344679901526
# 	P-Value for the ANOVA F-Value = 3.9990372634171427e-16
# 	Omega Squared = 0.02448585339982439
# num_1 x CC_1_num_1:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 1.9683412108383957e-13
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 3008.1856356521803
# 	P-Value for the ANOVA F-Value = 0.0
# 	Omega Squared = 0.7504482969037078
# num_2 x num_3:
# 	* kendall correlation = -0.2454324774924975 with a p-value of 2.5545028008839694e-90
# num_2 x num_4:
# 	* kendall correlation = 0.31782149605424026 with a p-value of 3.997455885703696e-150
# num_2 x num_5:
# 	* kendall correlation = 0.27808691786150935 with a p-value of 2.114793144301531e-115
# num_2 x num_c0_num_0:
# 	* kendall correlation = -0.5816392130710237 with a p-value of 0.0
# num_2 x num_c1_num_1:
# 	* kendall correlation = 0.0818597310214516 with a p-value of 1.798112392596339e-11
# num_2 x CN_0_num_0:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 1.9980696445313872e-86
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 1210.766085817764
# 	P-Value for the ANOVA F-Value = 0.0
# 	Omega Squared = 0.5474634141513979
# num_2 x CN_1_num_1:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 2.7611615574587242e-05
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 10.042786947565695
# 	P-Value for the ANOVA F-Value = 4.501978888075218e-08
# 	Omega Squared = 0.011913408707736477
# num_2 x CC_0_num_0:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 3.588272715546806e-90
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 1071.5270539607795
# 	P-Value for the ANOVA F-Value = 0.0
# 	Omega Squared = 0.5880313899382691
# num_2 x CC_1_num_1:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 0.0005639170637299809
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 13.391111108667596
# 	P-Value for the ANOVA F-Value = 1.1117125515573655e-08
# 	Omega Squared = 0.012239450714949597
# num_3 x num_4:
# 	* kendall correlation = -0.11499788818495053 with a p-value of 3.638773187873958e-21
# num_3 x num_5:
# 	* kendall correlation = 0.12475536289874403 with a p-value of 1.2628112160155834e-24
# num_3 x num_c0_num_0:
# 	* kendall correlation = 0.09547315771923975 with a p-value of 4.5289478467146586e-15
# num_3 x num_c1_num_1:
# 	* kendall correlation = 0.30148627320217847 with a p-value of 2.726379326492916e-135
# num_3 x CN_0_num_0:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 3.654173922416585e-05
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 16.80725911793392
# 	P-Value for the ANOVA F-Value = 7.948075087889442e-11
# 	Omega Squared = 0.015561277964935982
# num_3 x CN_1_num_1:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 5.047252933807101e-06
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 143.5858953741697
# 	P-Value for the ANOVA F-Value = 1.9361351324880225e-112
# 	Omega Squared = 0.15974473281856877
# num_3 x CC_0_num_0:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 1.1110590812776852e-05
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 24.011553256477363
# 	P-Value for the ANOVA F-Value = 1.4068273695071237e-19
# 	Omega Squared = 0.029768705473464465
# num_3 x CC_1_num_1:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 5.692877615277272e-06
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 177.54752825683627
# 	P-Value for the ANOVA F-Value = 5.941348633873846e-106
# 	Omega Squared = 0.15005558553032508
# num_4 x num_5:
# 	* kendall correlation = 0.2825684116927865 with a p-value of 4.363698569255595e-119
# num_4 x num_c0_num_0:
# 	* kendall correlation = -0.06203045459597644 with a p-value of 3.5179020886435283e-07
# num_4 x num_c1_num_1:
# 	* kendall correlation = 0.12560142269645438 with a p-value of 6.142553150230272e-25
# num_4 x CN_0_num_0:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 2.967495381797747e-146
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 216.72598668471184
# 	P-Value for the ANOVA F-Value = 3.112405151490135e-127
# 	Omega Squared = 0.1774462247640171
# num_4 x CN_1_num_1:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 0.0001425429640825458
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 9.225435082950696
# 	P-Value for the ANOVA F-Value = 2.0880846917561085e-07
# 	Omega Squared = 0.010848271110887785
# num_4 x CC_0_num_0:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 3.5538339301737195e-90
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 262.5671516707572
# 	P-Value for the ANOVA F-Value = 1.2342571513784435e-193
# 	Omega Squared = 0.2585761619866157
# num_4 x CC_1_num_1:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 6.266350865704465e-06
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 11.542444676182697
# 	P-Value for the ANOVA F-Value = 1.6039300002409393e-07
# 	Omega Squared = 0.010432461032906844
# num_5 x num_c0_num_0:
# 	* kendall correlation = -0.07606579971101478 with a p-value of 4.216374418694979e-10
# num_5 x num_c1_num_1:
# 	* kendall correlation = 0.07499210848060464 with a p-value of 7.383774950981439e-10
# num_5 x CN_0_num_0:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 5.754182510988882e-153
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 257.5375186468609
# 	P-Value for the ANOVA F-Value = 1.0877453834852427e-148
# 	Omega Squared = 0.20416224333923655
# num_5 x CN_1_num_1:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 2.2168701752137714e-08
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 19.414774787642425
# 	P-Value for the ANOVA F-Value = 8.726402759701707e-16
# 	Omega Squared = 0.023964628728971923
# num_5 x CC_0_num_0:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 2.8769849027732034e-96
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 305.08978982410963
# 	P-Value for the ANOVA F-Value = 2.2515402083262387e-220
# 	Omega Squared = 0.28848566105061263
# num_5 x CC_1_num_1:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 9.382647938505107e-07
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 23.7309652356932
# 	P-Value for the ANOVA F-Value = 3.553185641084995e-15
# 	Omega Squared = 0.022225752429872646
# num_c0_num_0 x num_c1_num_1:
# 	* kendall correlation = 0.0691621651661665 with a p-value of 1.3553292136441584e-08
# num_c0_num_0 x CN_0_num_0:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 9.629277145203657e-09
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 2853.871536317761
# 	P-Value for the ANOVA F-Value = 0.0
# 	Omega Squared = 0.7404533240794962
# num_c0_num_0 x CN_1_num_1:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 0.0030275917274025987
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 11.016109216516465
# 	P-Value for the ANOVA F-Value = 7.202862399973167e-09
# 	Omega Squared = 0.01317881173182217
# num_c0_num_0 x CC_0_num_0:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 3.4338209887903915e-50
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 2393.5020558485
# 	P-Value for the ANOVA F-Value = 0.0
# 	Omega Squared = 0.7613366716485745
# num_c0_num_0 x CC_1_num_1:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 0.002720636501538741
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 14.471349212292525
# 	P-Value for the ANOVA F-Value = 2.3325053135159773e-09
# 	Omega Squared = 0.013292284209872296
# num_c1_num_1 x CN_0_num_0:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 0.2413187146287583
# 	Valid Anova (Homoscedasticity data)?: True
# 	ANOVA F-Value = 20.913215457208278
# 	P-Value for the ANOVA F-Value = 2.089418184770066e-13
# 	Omega Squared = 0.019524421446271336
# num_c1_num_1 x CN_1_num_1:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 6.779472976962915e-50
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 2614.337999155071
# 	P-Value for the ANOVA F-Value = 0.0
# 	Omega Squared = 0.7770072469111302
# num_c1_num_1 x CC_0_num_0:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 0.34436171948686417
# 	Valid Anova (Homoscedasticity data)?: True
# 	ANOVA F-Value = 19.76679196968067
# 	P-Value for the ANOVA F-Value = 4.469756338826852e-16
# 	Omega Squared = 0.024411553888270467
# num_c1_num_1 x CC_1_num_1:
# 	ANOVA results:
# 	P-Value for the Levene's Test of Homoscedasticity = 1.626634480938016e-13
# 	Valid Anova (Homoscedasticity data)?: False
# 	ANOVA F-Value = 2994.82665062976
# 	P-Value for the ANOVA F-Value = 0.0
# 	Omega Squared = 0.7496135692713862
# CN_0_num_0 x CN_1_num_1:
# 	* Cramer's V = 0.0873 with a p-value of 0.0
# CN_0_num_0 x CC_0_num_0:
# 	* Cramer's V = 0.6074 with a p-value of 0.0
# CN_0_num_0 x CC_1_num_1:
# 	* Cramer's V = 0.0853 with a p-value of 0.0
# CN_1_num_1 x CC_0_num_0:
# 	* Cramer's V = 0.0862 with a p-value of 0.0
# CN_1_num_1 x CC_1_num_1:
# 	* Cramer's V = 0.6001 with a p-value of 0.0
# CC_0_num_0 x CC_1_num_1:
# 	* Cramer's V = 0.0928 with a p-value of 0.0
# ['num_0',
#  'num_1',
#  'num_2',
#  'num_3',
#  'num_4',
#  'num_5',
#  'CN_0_num_0',
#  'CN_1_num_1',
#  'CC_0_num_0',
#  'CC_1_num_1']

# %% [markdown]
# ## Check for correlations only between categorical variables

# %%
cor_feat = CorrelatedFeatures(
					method_num_num=None,
					method_num_cat=None,
					json_summary="./corr_json_examples/4_summary_cat.json",
					json_corr="./corr_json_examples/4_corr_cat.json",
					json_uncorr="./corr_json_examples/4_uncorr_cat.json"
				)
cor_feat.fit(df=df, label_col=label_col)
_ = cor_feat.get_summary()
cor_feat.get_selected_features()
# Out:
# No correlations detected. Nothing to be done here.
#
# CORRELATION SUMMARY
#
#
# NOT CORRELATED VARIABLES SUMMARY
#
# CN_0_num_0 x CN_1_num_1:
# 	* Cramer's V = 0.0873 with a p-value of 0.0
# CN_0_num_0 x CC_0_num_0:
# 	* Cramer's V = 0.6074 with a p-value of 0.0
# CN_0_num_0 x CC_1_num_1:
# 	* Cramer's V = 0.0853 with a p-value of 0.0
# CN_1_num_1 x CC_0_num_0:
# 	* Cramer's V = 0.0862 with a p-value of 0.0
# CN_1_num_1 x CC_1_num_1:
# 	* Cramer's V = 0.6001 with a p-value of 0.0
# CC_0_num_0 x CC_1_num_1:
# 	* Cramer's V = 0.0928 with a p-value of 0.0
# ['num_0',
#  'num_1',
#  'num_2',
#  'num_3',
#  'num_4',
#  'num_5',
#  'num_c0_num_0',
#  'num_c1_num_1',
#  'CN_0_num_0',
#  'CN_1_num_1',
#  'CC_0_num_0',
#  'CC_1_num_1']
